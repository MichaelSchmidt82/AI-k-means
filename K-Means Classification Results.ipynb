# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load text file with pasted data
data = np.loadtxt("iris-results.txt")

# %%
# Nrows is the number of samples
# Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 140)

# %%
# Calculate the mean -percentage- correct
# We used 10-fold random subsampling validation (10.0)
# Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
## Raw data
means
# Out:
# array([ 20.5,  58.9,  69.6,  69.3,  63.4,  42. ,  27.7,  25.6,  19.6,
#         20.4,  18.9,  17.9,  19.4,  19.4,  18.1,  18.4,  18.6,  19.8,
#         19.9,  17.4,  18.8,  19.4,  18.2,  19.3,  19.5,  18.5,  18.9,
#         19.3,  18.1,  18.5,  19.6,  19.6,  18.6,  19. ,  18. ,  20.4,
#         18.2,  19.3,  19.4,  18.3,  19.1,  18.9,  18.3,  18.5,  17.9,
#         19.9,  17.4,  20.3,  17.8,  19.3,  19.2,  19.2,  19.1,  19.3,
#         19.8,  18.4,  17.1,  19.1,  17.7,  17.6,  19.1,  17.7,  19.3,
#         18.9,  18.7,  18.7,  19.1,  21. ,  19. ,  20.2,  18.2,  19.1,
#         19.2,  18.2,  17.6,  18.6,  17.9,  19.2,  19. ,  19. ,  20.1,
#         19.3,  18.9,  18.4,  19.2,  18.4,  18. ,  19.7,  19.2,  19.9,
#         18.6,  18.1,  17.6,  19.3,  18.7,  17.5,  19.7,  19.1,  18.8,
#         18.2,  19.4,  21.1,  18.5,  20.8,  18.9,  17.7,  17.9,  19.5,
#         19. ,  19.5,  19.6,  16.9,  17.7,  19.6,  20.7,  18.7,  19.6,
#         20.2,  18. ,  19.8,  18.7,  20. ,  17.6,  20.3,  17.6,  19.1,
#         17.4,  18.2,  19.6,  18. ,  19.4,  20.2,  18. ,  19.7,  19.1,
#         19.3,  19. ,  17.7,  19.1,  19.8])

# %%
# Standard error is the standard deviation (np.std) / sqrt(N-1)
# Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0

# %%
## Raw data
stderr
# Out:
# array([ 0.83333333,  1.58843675,  2.39072281,  2.80423561,  3.09845188,
#         3.22239637,  2.44476352,  2.11927184,  1.06287204,  1.12743564,
#         0.83961271,  0.86800596,  0.72222999,  0.81426673,  0.86099543,
#         0.78778554,  0.80428147,  0.85256594,  0.77191877,  0.83629776,
#         0.79493345,  0.736083  ,  0.88054161,  0.81964516,  0.80872765,
#         0.82112266,  0.8274947 ,  0.80722745,  0.74799395,  0.83333333,
#         0.79034579,  0.73745399,  0.7787584 ,  0.79772404,  0.77849894,
#         0.72362723,  0.89193921,  0.79461572,  0.7890667 ,  0.85345406,
#         0.80522285,  0.87496032,  0.84153539,  0.7703469 ,  0.7692972 ,
#         0.91557787,  0.98082629,  0.846323  ,  0.78598841,  0.76877181,
#         0.78727249,  0.82486607,  0.80522285,  0.81964516,  0.82853162,
#         0.6922369 ,  0.728843  ,  0.82993245,  0.82700628,  0.79289777,
#         0.76666667,  0.87449841,  0.79461572,  0.87496032,  0.77400963,
#         0.86052603,  0.79257922,  0.78495963,  0.78495963,  0.75183278,
#         0.80879009,  0.77973059,  0.78727249,  0.86899454,  0.88898989,
#         0.8764022 ,  0.84441122,  0.70610612,  0.78495963,  0.78495963,
#         0.75872035,  0.83187752,  0.76402708,  0.84947994,  0.78727249,
#         0.82535575,  0.82877541,  0.79715403,  0.83702214,  0.77191877,
#         0.81674397,  0.87264836,  0.83023667,  0.75551842,  0.86052603,
#         0.83333333,  0.846323  ,  0.87726619,  0.75585259,  0.79620311,
#         0.7890667 ,  0.75068992,  0.79613968,  0.70610612,  0.81519657,
#         0.81470079,  0.84441122,  0.80872765,  0.81028739,  0.82112266,
#         0.79034579,  0.86099543,  0.83913134,  0.83991342,  0.71428427,
#         0.78695167,  0.80302459,  0.76515002,  0.73854895,  0.81624912,
#         0.76084748,  0.79136757,  0.84231523,  0.82210619,  0.83023667,
#         0.75337624,  0.83629776,  0.86899454,  0.70953107,  0.82877541,
#         0.7890667 ,  0.73827536,  0.765414  ,  0.77139517,  0.76666667,
#         0.71428427,  0.79772404,  0.80220655,  0.80522285,  0.80377895])

# %%
# Make the plot bigger to get a better resolution
plt.figure(figsize=(24,8));

# Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);

# Fix the axis labels
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');

# %%
## Same calculation on the cancer data set
data = np.loadtxt("cancer-results.txt")

# %%
np.shape(data)
# Out:
# (100, 95)

# %%
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
means
# Out:
# array([ 14. ,  34.2,  40.6,  43.2,  46.6,  50.2,  50.1,  53.2,  55.8,
#         57.2,  56. ,  60. ,  57.9,  59.9,  58.7,  61.5,  59. ,  58.1,
#         60.9,  59.7,  60.1,  60.8,  61.2,  63.2,  62.5,  60.7,  63.7,
#         61.7,  60.7,  61.7,  62.4,  63.1,  63.6,  62.3,  63.5,  59.8,
#         65.4,  61.5,  62.3,  62.5,  63.3,  65. ,  64.4,  62.8,  66.4,
#         63.2,  64.8,  64.9,  62.8,  63.5,  65.1,  64. ,  62.3,  65.5,
#         63.7,  63.6,  65.4,  67.5,  65.2,  70.5,  66.3,  67.2,  64.9,
#         67.2,  67. ,  63. ,  64.9,  65. ,  64. ,  68.8,  67.2,  67.1,
#         69. ,  67.3,  67.8,  67.1,  66.7,  68.2,  65.9,  70.2,  66.9,
#         67.6,  68.5,  66.8,  66.7,  68.9,  67.7,  67.6,  67.9,  68.2,
#         67.1,  68.3,  68.4,  69.7,  71.7])

# %%
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0])-1)

# %%
plt.figure(figsize=(24,8));
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');
