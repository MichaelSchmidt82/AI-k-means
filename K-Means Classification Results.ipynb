# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load text file with pasted data
data = np.loadtxt("iris-results.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-19deabc0c511> in <module>()
#       1 # Load text file with pasted data
# ----> 2 data = np.loadtxt("iris-results.txt")
#
# /usr/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     896                 fh = iter(open(fname, 'U'))
#     897             else:
# --> 898                 fh = iter(open(fname))
#     899         else:
#     900             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris-results.txt'

# %%
# Nrows is the number of samples
# Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 95)

# %%
# Calculate the mean -percentage- correct
# We used 10-fold random subsampling validation (10.0)
# Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
## Raw data
means
# Out:
# array([ 15.4,  35.4,  41.7,  46. ,  46.3,  50.9,  49.6,  53.9,  53.5,
#         57.9,  56.6,  56.1,  58.9,  60.2,  60.9,  58. ,  62.9,  60.9,
#         60.4,  61. ,  59.5,  60.9,  59.1,  62.3,  60. ,  63. ,  59.5,
#         63.4,  64.5,  61. ,  58.6,  62.5,  64.5,  62.3,  61.4,  65.4,
#         61.5,  63.5,  61.6,  62.8,  59.6,  63. ,  63. ,  64.2,  61.3,
#         62.4,  61.8,  63.4,  64.5,  63.4,  64.3,  63.7,  60.3,  66.1,
#         66.2,  65.6,  64.4,  65. ,  66. ,  65.8,  66.5,  65.3,  65.7,
#         64.5,  68. ,  66.2,  65.6,  63.8,  68. ,  67.6,  66. ,  67.4,
#         65.2,  66.3,  69.4,  67.6,  67.4,  66.5,  69.1,  67.1,  65. ,
#         68.7,  68.1,  69.1,  70.3,  67.3,  66.5,  68.3,  68.4,  66.2,
#         68. ,  68. ,  69.1,  69.5,  69.7])

# %%
# Standard error is the standard deviation (np.std) / sqrt(N-1)
# Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0

# %%
## Raw data
stderr
# Out:
# array([ 0.98903075,  1.74899683,  1.64565544,  1.53082799,  1.67365203,
#         1.57053037,  1.67525062,  1.54981263,  1.61667448,  1.49946118,
#         1.42998199,  1.65080329,  1.52351932,  1.68762579,  1.71796803,
#         1.59544807,  1.51287405,  1.52484475,  1.36270675,  1.60491669,
#         1.6414763 ,  1.48456707,  1.49811329,  1.56253485,  1.51090313,
#         1.64224532,  1.62291047,  1.50567948,  1.33617122,  1.50755672,
#         1.58286277,  1.40255899,  1.54641978,  1.50322885,  1.59557469,
#         1.41721023,  1.61041434,  1.61041434,  1.48201337,  1.27191894,
#         1.52368506,  1.53412364,  1.52752523,  1.38666084,  1.52192727,
#         1.49828184,  1.32862806,  1.60944184,  1.37344954,  1.42998199,
#         1.41603373,  1.46787141,  1.431641  ,  1.5432813 ,  1.47559267,
#         1.47244043,  1.45865581,  1.4106378 ,  1.34839972,  1.36463263,
#         1.31329642,  1.41031553,  1.4016945 ,  1.48647098,  1.31040899,
#         1.59405461,  1.37304498,  1.33922939,  1.49071198,  1.39349136,
#         1.39262125,  1.40432233,  1.42474524,  1.58053181,  1.44823124,
#         1.42927544,  1.34555009,  1.44512416,  1.25605604,  1.50618254,
#         1.45296631,  1.32310471,  1.51554237,  1.34160314,  1.25089867,
#         1.30155307,  1.53987406,  1.44986938,  1.33121043,  1.39102462,
#         1.32573593,  1.39985569,  1.33405284,  1.35866096,  1.29844507])

# %%
# Make the plot bigger to get a better resolution
plt.figure(figsize=(24,8));

# Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);

# Fix the axis labels
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');

# %%
## Same calculation on the cancer data set
data = np.loadtxt("cancer-results.txt")

# %%
np.shape(data)
# Out:
# (100, 95)

# %%
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
means
# Out:
# array([ 15.4,  35.4,  41.7,  46. ,  46.3,  50.9,  49.6,  53.9,  53.5,
#         57.9,  56.6,  56.1,  58.9,  60.2,  60.9,  58. ,  62.9,  60.9,
#         60.4,  61. ,  59.5,  60.9,  59.1,  62.3,  60. ,  63. ,  59.5,
#         63.4,  64.5,  61. ,  58.6,  62.5,  64.5,  62.3,  61.4,  65.4,
#         61.5,  63.5,  61.6,  62.8,  59.6,  63. ,  63. ,  64.2,  61.3,
#         62.4,  61.8,  63.4,  64.5,  63.4,  64.3,  63.7,  60.3,  66.1,
#         66.2,  65.6,  64.4,  65. ,  66. ,  65.8,  66.5,  65.3,  65.7,
#         64.5,  68. ,  66.2,  65.6,  63.8,  68. ,  67.6,  66. ,  67.4,
#         65.2,  66.3,  69.4,  67.6,  67.4,  66.5,  69.1,  67.1,  65. ,
#         68.7,  68.1,  69.1,  70.3,  67.3,  66.5,  68.3,  68.4,  66.2,
#         68. ,  68. ,  69.1,  69.5,  69.7])

# %%
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0])-1)

# %%
plt.figure(figsize=(24,8));
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');
