# %%
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load text file with pasted data
data = np.loadtxt("iris-results.txt")

# %%
# Nrows is the number of samples
# Ncolumns is the number of clusters (1 to N)
np.shape(data)
# Out:
# (100, 95)

# %%
# Calculate the mean -percentage- correct
# We used 10-fold random subsampling validation (10.0)
# Apply the np.mean() function across the rows (axis 0, one mean per column)
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
## Raw data
means
# Out:
# array([17.1, 33. , 41.3, 43.4, 46.8, 49.9, 50.2, 51.7, 53.2, 57.2, 57.2,
#        56.1, 59.3, 59.9, 62.3, 60.4, 59.4, 61. , 60.5, 60.2, 60. , 60.1,
#        59.6, 63.7, 59.9, 60.3, 62. , 59.4, 61.4, 61.2, 61.5, 62.1, 59.3,
#        59.9, 60.7, 60.7, 62. , 60.5, 64.6, 63.6, 62.3, 66. , 62.2, 60.9,
#        66.1, 63.3, 63.1, 64.9, 61.9, 65.2, 61.2, 64.4, 65. , 64.3, 65.1,
#        66.1, 64.8, 65. , 63.6, 65.8, 66.8, 63.5, 68.3, 65.3, 64.8, 67. ,
#        67.4, 65.8, 69.6, 65.3, 67.6, 69.6, 69.6, 65.9, 66.1, 67.4, 68.4,
#        68.8, 68.6, 67. , 69.2, 66.9, 70.3, 68. , 67. , 67.6, 67.8, 69.6,
#        68.7, 67.8, 69. , 71.1, 68.9, 69.9, 69.1])

# %%
# Standard error is the standard deviation (np.std) / sqrt(N-1)
# Alternatively, we just use scipy.stats.sem() [sps.sem()]
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0]-1))
stderr = np.apply_along_axis(sps.sem,0,data)*100.0/10.0

# %%
## Raw data
stderr
# Out:
# array([0.89097608, 1.64838458, 1.62465225, 1.5519294 , 1.58196911,
#        1.5142088 , 1.6816298 , 1.54432817, 1.53003598, 1.58961275,
#        1.47079309, 1.43474208, 1.4016945 , 1.48047904, 1.49649422,
#        1.65095626, 1.58158596, 1.62989744, 1.5594288 , 1.38520319,
#        1.43548113, 1.33707807, 1.69324266, 1.42598539, 1.63605216,
#        1.53382732, 1.47709789, 1.56230857, 1.53754363, 1.50608195,
#        1.55293791, 1.55891052, 1.43727436, 1.45986716, 1.42314916,
#        1.4016945 , 1.54396839, 1.38808057, 1.55323059, 1.56036774,
#        1.50322885, 1.31040899, 1.40403459, 1.41489194, 1.39909783,
#        1.4002525 , 1.58078743, 1.34461139, 1.54850857, 1.50742271,
#        1.49260805, 1.57838941, 1.42488702, 1.35030861, 1.4319232 ,
#        1.530135  , 1.49396091, 1.57954091, 1.4806496 , 1.41549863,
#        1.39175059, 1.53987406, 1.46373674, 1.52722763, 1.59848413,
#        1.3889899 , 1.46073179, 1.32710667, 1.42076946, 1.49379187,
#        1.24819061, 1.42076946, 1.46280483, 1.28782175, 1.2704489 ,
#        1.42573745, 1.28487707, 1.30484722, 1.26347285, 1.3889899 ,
#        1.4885421 , 1.39765316, 1.30620122, 1.42842712, 1.19341628,
#        1.33424211, 1.40403459, 1.42076946, 1.26853929, 1.26794194,
#        1.32954006, 1.30186347, 1.39909783, 1.36696227, 1.29564149])

# %%
# Make the plot bigger to get a better resolution
plt.figure(figsize=(24,8));

# Use an error bar plot...
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);

# Fix the axis labels
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');

# %%
## Same calculation on the cancer data set
data = np.loadtxt("cancer-results.txt")

# %%
np.shape(data)
# Out:
# (100, 95)

# %%
means = np.apply_along_axis(np.mean,0,data)*100.0/10.0

# %%
means
# Out:
# array([17.1, 33. , 41.3, 43.4, 46.8, 49.9, 50.2, 51.7, 53.2, 57.2, 57.2,
#        56.1, 59.3, 59.9, 62.3, 60.4, 59.4, 61. , 60.5, 60.2, 60. , 60.1,
#        59.6, 63.7, 59.9, 60.3, 62. , 59.4, 61.4, 61.2, 61.5, 62.1, 59.3,
#        59.9, 60.7, 60.7, 62. , 60.5, 64.6, 63.6, 62.3, 66. , 62.2, 60.9,
#        66.1, 63.3, 63.1, 64.9, 61.9, 65.2, 61.2, 64.4, 65. , 64.3, 65.1,
#        66.1, 64.8, 65. , 63.6, 65.8, 66.8, 63.5, 68.3, 65.3, 64.8, 67. ,
#        67.4, 65.8, 69.6, 65.3, 67.6, 69.6, 69.6, 65.9, 66.1, 67.4, 68.4,
#        68.8, 68.6, 67. , 69.2, 66.9, 70.3, 68. , 67. , 67.6, 67.8, 69.6,
#        68.7, 67.8, 69. , 71.1, 68.9, 69.9, 69.1])

# %%
stderr = np.apply_along_axis(np.std,0,data)*100.0/(10.0*np.sqrt(np.shape(data)[0])-1)

# %%
plt.figure(figsize=(24,8));
plt.errorbar(np.array(range(len(means)))+1.0,means,yerr=stderr);
plt.xlabel('Number of Clusters (K)');
plt.ylabel('Percentage Correct (%) [+- Std. Err.]');
